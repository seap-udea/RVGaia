# %% [markdown]
# # Proper Motions and Radial Velocities Catalogue

# %%
#Libraries
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
#Directory
datadir="Data-Gaia/RV-Catalogue/"
#Dictionaries
data=dict()
match=dict()
RVcat=pd.DataFrame()

# %% [markdown]
# ## GAIA Data

# %%
#GAIA
name="GAIA"
data[name]=pd.read_csv(datadir+"TGAS-50pc.csv")
cats=['hip','tycho2_id']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
data[name]['hip']=data[name]['hip'].apply(lambda x:x.replace('.0',''))
print("Number of objects in %s = "%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
data[name]=data[name].rename(columns={'tycho2_id':'TYC2','hip':'HIP'})
# Out:
# /Users/jzuluaga/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Number of objects in GAIA =  1564293
# Number of objects in catalogue hip: 88392
# Number of objects in catalogue tycho2_id: 1475901

# %% [markdown]
# ## RV Catalogues

# %%
#MALDONADO2010
name="Maldonado2010.tsv"
comments=list(range(82))+[83,84]
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name,sep=";",skiprows=comments)
cats=['HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"]
df["eRV"]=data[name]["e_RV"]
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Maldonado2010.tsv: 495
# Number of objects in catalogue HIP: 495
# Median error: 0.11
# Number of entries with zero error: 35
# Filtered catalogue: 473

# %%
#WEB1995
#III/213/catalog
name="Web1995-HIP.csv"
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name)
cats=['HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=data[name]["e_RV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Web1995-HIP.csv: 494
# Number of objects in catalogue HIP: 494
# Median error: 1.7
# Number of entries with zero error: 0
# Filtered catalogue: 494

# %%
#WEB1995-TYC2
#III/213/catalog
name="Web1995-TYC2.csv"
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name)
cats=['TYC2','HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=data[name]["e_RV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Web1995-TYC2.csv: 673
# Number of objects in catalogue TYC2: 673
# Number of objects in catalogue HIP: 495
# Median error: 1.9
# Number of entries with zero error: 1
# Filtered catalogue: 673

# %%
#GCS2011
#J/A+A/530/A138/catalog
name="GCS2011.tsv"
comments=list(range(174))+[175,176]
data[name]=pd.read_csv(datadir+name,sep="|",skiprows=comments)
cats=['HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=data[name]["e_RV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# /Users/jzuluaga/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Number of objects in GCS2011.tsv: 16682
# Number of objects in catalogue HIP: 14955
# Median error: 0.4
# Number of entries with zero error: 1678
# Filtered catalogue: 14139

# %%
#RAVE-DR5
#III/279/rave_dr5
name="RAVE-DR5.tsv"
comments=list(range(78))+[79,80]
data[name]=pd.read_csv(datadir+name,sep=";",skiprows=comments)
cats=['TYCHO2']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="RAJ2000",DECJ2000="DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["HRV"].map(str)
df["eRV"]=data[name]["e_HRV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in RAVE-DR5.tsv: 520701
# Number of objects in catalogue TYCHO2: 309596
# Median error: 1.189
# Number of entries with zero error: 217
# Filtered catalogue: 520701

# %%
#PULKOVO
#III/252/table8
name="Pulkovo.tsv"
comments=list(range(61))+[62,63]
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name,sep=";",skiprows=comments)
cats=['HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RA",DECJ2000="_DE")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=data[name]["eRV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Pulkovo.tsv: 35493
# Number of objects in catalogue HIP: 35493
# Median error: 1.6
# Number of entries with zero error: 24715
# Filtered catalogue: 35493

# %%
#FAMAEY2005
#J/A+A/430/165/tablea1
name="Famaey2005.tsv"
comments=list(range(118))+[119,120]
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name,sep=";",skiprows=comments)
cats=['HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=data[name]["e_RV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Famaey2005.tsv: 6690
# Number of objects in catalogue HIP: 6690
# Median error: 0.22
# Number of entries with zero error: 0
# Filtered catalogue: 6028

# %%
#BB2000
#III/213/catalogue
name="BB2000.csv"
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name)
cats=['TYC2','HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=data[name]["e_RV"].map(str)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in BB2000.csv: 673
# Number of objects in catalogue TYC2: 673
# Number of objects in catalogue HIP: 495
# Median error: 1.9
# Number of entries with zero error: 1
# Filtered catalogue: 673

# %%
#MALARODA2012
#III/249/catalog
name="Malaroda2012.csv"
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name)
cats=['TYC2','HIP']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="_RAJ2000",DECJ2000="_DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=1.0;df["eRV"]=df["eRV"].map(str) #TYPICAL VALUE FOR OTHER CATALOGUES
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Malaroda2012.csv: 2178
# Number of objects in catalogue TYC2: 2178
# Number of objects in catalogue HIP: 866
# Median error: 1.0
# Number of entries with zero error: 0
# Filtered catalogue: 2178

# %%
#GALAH I
#J/MNRAS/465/3203/catal
name="Galah.tsv"
comments=list(range(54))+[55,56]
data[name]=pd.read_csv("Data-Gaia/RV-Catalogue/%s"%name,sep=";",skiprows=comments)
cats=['TYC2']
for cname in cats:
    data[name][cname]=data[name][cname].fillna('')
    data[name][cname]=data[name][cname].map(str)
dfstr=data[name].select_dtypes(['object'])
data[name][dfstr.columns]=dfstr.apply(lambda x: x.str.strip())
print("Number of objects in %s:"%name,len(data[name]))
for cat in cats:
    cond=data[name][cat]!=''
    print("Number of objects in catalogue %s:"%cat,len(data[name][cat][cond]))
#STORING RESULTS
df=pd.DataFrame()
if not 'TYC2' in data[name].columns:df["TYC2"]=''
else:df["TYC2"]=data[name]["TYC2"]
if not 'HIP' in data[name].columns:df["HIP"]=''
else:df["HIP"]=data[name]["HIP"].apply(lambda x:x.replace('.0',''))
COORDS=dict(RAJ2000="RAJ2000",DECJ2000="DEJ2000")
for C in COORDS.keys():df[C]=data[name][COORDS[C]]
df["RV"]=data[name]["RV"].map(str)
df["eRV"]=0.6;df["eRV"]=df["eRV"].map(str) #Martell et al. (2017)
df["CAT"]=name
#ZERO ERRORS
cond=df.RV==''
df=df.drop(df.index[cond])
df.RV=df.RV.map(float)
df.eRV[df.eRV=='']=0.0
df.eRV=df.eRV.map(float)
med=df.eRV[df.eRV>0].median()
print("Median error:",med)
print("Number of entries with zero error:",len(df.eRV[df.eRV==0]))
df.eRV[df.eRV==0]=med
#RESULTING SIZE
print("Filtered catalogue:",len(df))
#FILLNA
RVcat=RVcat.append(df.fillna(''))
# Out:
# Number of objects in Galah.tsv: 10680
# Number of objects in catalogue TYC2: 10680
# Median error: 0.6
# Number of entries with zero error: 0
# Filtered catalogue: 10680

# %%
df
# Out:
#                TYC2 HIP     RAJ2000   DECJ2000       RV  eRV        CAT
# 0      9512-01937-1      209.883824 -84.842534   19.422  0.6  Galah.tsv
# 1      9508-02667-1      204.390079 -84.345997   39.962  0.6  Galah.tsv
# 2      9509-01044-1      215.147413 -84.313541   34.000  0.6  Galah.tsv
# 3      9508-02321-1      204.643099 -84.188659    8.263  0.6  Galah.tsv
# 4      9508-02638-1      208.436880 -84.182460   32.238  0.6  Galah.tsv
# 5      9509-00704-1      211.855996 -84.102053   22.343  0.6  Galah.tsv
# 6      9509-02342-1      210.798951 -83.533936  -23.160  0.6  Galah.tsv
# 7      9508-02273-1      209.925664 -83.460497  -16.954  0.6  Galah.tsv
# 8      9508-01621-1      206.645988 -83.421809    1.803  0.6  Galah.tsv
# 9      9509-02211-1      211.696198 -83.369708  -10.700  0.6  Galah.tsv
# 10     9508-00217-1      209.111384 -83.336493   -1.356  0.6  Galah.tsv
# 11     9440-00171-1      226.823238 -82.233843    5.900  0.6  Galah.tsv
# 12     9440-00081-1      227.267394 -82.139937  -25.339  0.6  Galah.tsv
# 10676  0767-00043-1      109.228924   9.499653   89.534  0.6  Galah.tsv
# 10677  0766-00688-1      109.026823   9.521511    0.945  0.6  Galah.tsv
# 10678  0767-01363-1      109.495299   9.556857  -34.416  0.6  Galah.tsv
# 10679  0767-01211-1      109.563095   9.560245   88.872  0.6  Galah.tsv
#
# [10680 rows x 7 columns]

# %% [markdown]
# ## RV Cat

# %%
#Save Raw RVcat
RVcat.to_csv(datadir+"RVcat_raw.csv")

# %%
#Reset index
RVcatf=RVcat.reset_index(drop=True)
print("Number of unfiltered entries:",len(RVcatf))
print("Catalogues included:",np.unique(RVcat.CAT.values))
RVcatf.is_copy=False
cond=RVcatf.RV==''
RVcatf=RVcatf.drop(RVcatf.index[cond])
RVcatf.RV=RVcatf.RV.map(float)
cond=RVcatf.eRV==''
RVcatf=RVcatf.drop(RVcatf.index[cond])
RVcatf.eRV=RVcatf.eRV.map(float)
print("Number of filtered entries:",len(RVcatf))
RVcatf.to_csv(datadir+"RVcatf.csv")
# Out:
# Number of unfiltered entries: 591532
# Catalogues included: ['BB2000.csv' 'Famaey2005.tsv' 'GCS2011.tsv' 'Galah.tsv' 'Malaroda2012.csv'
#  'Maldonado2010.tsv' 'Pulkovo.tsv' 'RAVE-DR5.tsv' 'Web1995-HIP.csv'
#  'Web1995-TYC2.csv']
# Number of filtered entries: 590333

# %%
print(RVcatf.columns)
# Out:
# Index(['TYC2', 'HIP', 'RV', 'eRV', 'CAT'], dtype='object')

# %%
#Timeit
import timeit
mytimer=lambda:timeit.default_timer()
start_time = timeit.default_timer()
ti=mytimer()
a=1
te=mytimer()
elapsed = timeit.default_timer() - start_time
print(elapsed)
elapsed=te-ti
print(elapsed)
# Out:
# 0.0001201940031023696
# 5.432400212157518e-05

# %%
#Remove duplicate entries
ids=""
k=0
indexes=[]
ti=mytimer()
Nfreq=10
Ntot=10*Nfreq
for TYC2,HIP in zip(RVcatf.TYC2.values,RVcatf.HIP.values):
    if (k%Nfreq)==0:
        te=mytimer()
        print("Entry %d (time = %.3e)..."%(k,te-ti))
        ti=mytimer()
    if TYC2!='':
        rep=RVcatf[RVcatf.TYC2==TYC2].sort_values('eRV')
        if(len(rep)>1):indexes+=list(rep.index[1:])
    elif HIP!='':
        rep=RVcatf[RVcatf.HIP==HIP].sort_values('eRV')
        if(len(rep)>1):indexes+=list(rep.index[1:])
    k+=1
    if k>Ntot:break

RVcatf=RVcatf.drop(indexes)
#RVcatf.to_csv(datadir+"RVcat.csv")
print("Catalogue after removing repeated entries:",len(RVcatf))
    #elif HIP!='':
    #    rep=RVcatf[RVcatf.HIP==HIP].sort_values('eRV')
    #    if(len(rep)>1):
    #        print(rep)
    #        RVcatf=RVcatf.drop(rep.index[1:])
    #        rep=RVcatf[RVcatf.HIP==HIP].sort_values('eRV')
    #        print(rep)
    #    break
# Out:
# Entry 0 (time = 1.017e-03)...
# Entry 10 (time = 7.192e-01)...
# Entry 20 (time = 7.169e-01)...
# Entry 30 (time = 7.127e-01)...
# Entry 40 (time = 7.102e-01)...
# Entry 50 (time = 6.771e-01)...
# Entry 60 (time = 6.812e-01)...
# Entry 70 (time = 8.207e-01)...
# Entry 80 (time = 7.284e-01)...
# Entry 90 (time = 7.185e-01)...
# Entry 100 (time = 7.585e-01)...
# Catalogue after removing repeated entries: 590174
